# %%
# %pip install markdownify
# Out:
# Requirement already satisfied: markdownify in /home/vlad/anaconda3/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in /home/vlad/anaconda3/lib/python3.12/site-packages (from markdownify) (4.14.2)
# Requirement already satisfied: six<2,>=1.15 in /home/vlad/anaconda3/lib/python3.12/site-packages (from markdownify) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/vlad/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/vlad/anaconda3/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.9->markdownify) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
import requests
from urllib.parse import urljoin, urlparse
from bs4 import BeautifulSoup
import time
from datetime import datetime, timezone
from markdownify import markdownify as md
import re
from bs4 import BeautifulSoup

# %%
START_URL = "https://cloud.ru/docs/tutorials-evolution/list/index"
BASE_URL = "https://cloud.ru"
TOPICS_PREFIX = "/docs/tutorials-evolution/list/topics/"
OUTPUT_FILE = "cloud_ru_docs.jsonl"

# %%
def get_page_html(url):
    headers = {
        "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36"
    }
    try:
        resp = requests.get(url, headers=headers, timeout=10)
        resp.raise_for_status()
        return resp.text
    except Exception as e:
        print(f"Ошибка при загрузке {url}: {e}")
        return None

# %%
def extract_topic_links(html):
    soup = BeautifulSoup(html, 'html.parser')
    links = set()

    for a in soup.find_all('a', href=True):
        href = a['href']
        if href.startswith(TOPICS_PREFIX):
            full_url = urljoin(BASE_URL, href)
            links.add(full_url)
    return sorted(links)

# %%
def extract_title_and_content(html):
    soup = BeautifulSoup(html, 'html.parser')

    for selector in [
        'header', 'nav', 'footer', '.sidebar', 'script', 'style',
        '.breadcrumbs', '.toc', '.header-anchor', '.edit-page-link',
        '.feedback-form', '.article-meta', '.pagination',
        # Удаляем также футер с юр. ссылками и копирайтом
        'p:contains("© 2025 Cloud.ru")',
        'a[href*="documents"]', 'a[href*="technical-support"]'
    ]:
        for tag in soup.select(selector):
            tag.decompose()

    title_tag = soup.find('h1')
    title = title_tag.get_text(strip=True) if title_tag else "Без заголовка"

    main_content = (
        soup.find('article') or
        soup.find('main') or
        soup.select_one('.content') or
        soup
    )

    def convert_tag(tag):
        if not hasattr(tag, 'name'):
            return str(tag).strip()

        if tag.name in ['h1', 'h2', 'h3', 'h4', 'h5', 'h6']:
            level = int(tag.name[1])
            text = tag.get_text().strip()
            return f"{'#' * level} {text}" if text else ""

        elif tag.name == 'p':
            return tag.get_text().strip()

        elif tag.name in ['ul', 'ol']:
            items = []
            for li in tag.find_all('li', recursive=False):
                prefix = '- ' if tag.name == 'ul' else f"{len(items)+1}. "
                inner = ''.join(convert_tag(child) for child in li.children)
                items.append(prefix + inner.strip())
            return '\n'.join(items)

        elif tag.name == 'pre':
            code_text = tag.get_text()
            if code_text.strip():
                return f"```\n{code_text.rstrip()}\n```"
            return ""

        elif tag.name == 'code':
            code_text = tag.get_text()
            if code_text.strip():
                return f"`{code_text}`"
            return ""

        elif tag.name == 'a':
            href = tag.get('href', '').strip()
            text = tag.get_text().strip()
            if href and text:
                if href.startswith('/'):
                    href = 'https://cloud.ru' + href
                return f"[{text}]({href})"
            return text

        elif hasattr(tag, 'children'):
            return ''.join(convert_tag(child) for child in tag.children)

        else:
            return tag.get_text() if tag.string else ""

    blocks = []
    for child in main_content.children:
        if hasattr(child, 'name') and child.name:
            block = convert_tag(child).strip()
            if block:
                blocks.append(block)

    markdown_text = '\n\n'.join(blocks)

    lines = markdown_text.splitlines()
    cleaned_lines = []
    for line in lines:
        # Удаляем явный шум
        if re.search(r'\$!\.\$|руководство пользователя облако|документация Практические', line, re.IGNORECASE):
            continue
        cleaned_lines.append(line)

    markdown_text = '\n'.join(cleaned_lines).strip()

    markdown_text = re.sub(r'([а-яА-Яa-zA-Z])([А-Я][а-я])', r'\1 \2', markdown_text)

    return title, markdown_text

# %%
def main():
    print("📥 Загружаем стартовую страницу...")
    index_html = get_page_html(START_URL)
    if not index_html:
        print("Не удалось загрузить стартовую страницу.")
        return

    print("Извлекаем ссылки на статьи...")
    topic_urls = extract_topic_links(index_html)
    if not topic_urls:
        print("Не найдено ни одной ссылки на статьи.")
        return

    print(f"Найдено {len(topic_urls)} статей. Начинаем скачивание...\n")

    with open(OUTPUT_FILE, 'w', encoding='utf-8') as out_f:
        for i, url in enumerate(topic_urls, 1):
            print(f"[{i}/{len(topic_urls)}] {url}")
            html = get_page_html(url)
            if not html:
                continue

            title, content = extract_title_and_content(html)

            path = urlparse(url).path
            section = path.strip('/').split('/')[-1].replace('-', ' ').title()

            record = {
                "url": url,
                "title": title,
                "content": content,
                "section": section,
                "source": "cloud.ru",
                "timestamp": datetime.now(timezone.utc).isoformat().replace('+00:00', 'Z')
            }

            out_f.write(json.dumps(record, ensure_ascii=False) + "\n")
            time.sleep(0.3)

    print(f"\nГотово! Все статьи сохранены в {OUTPUT_FILE}")

# %%
if __name__ == "__main__":
    main()
# Out:
# 📥 Загружаем стартовую страницу...
# Извлекаем ссылки на статьи...
# Найдено 108 статей. Начинаем скачивание...
#
# [1/108] https://cloud.ru/docs/tutorials-evolution/list/topics/arenadata-db__adbc-backup?source-platform=Evolution
# [2/108] https://cloud.ru/docs/tutorials-evolution/list/topics/arenadata-db__dbeaver?source-platform=Evolution
# [3/108] https://cloud.ru/docs/tutorials-evolution/list/topics/arenadata-db__managed-bi?source-platform=Evolution
# [4/108] https://cloud.ru/docs/tutorials-evolution/list/topics/arenadata-db__vm-local-ip?source-platform=Evolution
# [5/108] https://cloud.ru/docs/tutorials-evolution/list/topics/bare-metal__1c_deploy?source-platform=Evolution
# [6/108] https://cloud.ru/docs/tutorials-evolution/list/topics/bare-metal__highload_app?source-platform=Evolution
# [7/108] https://cloud.ru/docs/tutorials-evolution/list/topics/bare-metal__k3s?source-platform=Evolution
# [8/108] https://cloud.ru/docs/tutorials-evolution/list/topics/bare-metal__llm_deploy?source-platform=Evolution
# [9/108] https://cloud.ru/docs/tutorials-evolution/list/topics/bare-metal__onlyoffice?source-platform=Evolution
# [10/108] https://cloud.ru/docs/tutorials-evolution/list/topics/bare-metal__postgre_deploy?source-platform=Evolution
# [11/108] https://cloud.ru/docs/tutorials-evolution/list/topics/container-apps__before-work?source-platform=Evolution
# [12/108] https://cloud.ru/docs/tutorials-evolution/list/topics/container-apps__ci-cd?source-platform=Evolution
# [13/108] https://cloud.ru/docs/tutorials-evolution/list/topics/container-apps__deploy-backend-app?source-platform=Evolution
# [14/108] https://cloud.ru/docs/tutorials-evolution/list/topics/container-apps__deploy-django-photo-app?source-platform=Evolution
# [15/108] https://cloud.ru/docs/tutorials-evolution/list/topics/container-apps__deploy-frontend-app?source-platform=Evolution
# [16/108] https://cloud.ru/docs/tutorials-evolution/list/topics/container-apps
108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-rag__connect-mcp-chatbox?source-platform=Evolution
# [72/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-rag__create-agent?source-platform=Evolution
# [73/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-rag__create-inference?source-platform=Evolution
# [74/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-rag__json-files?source-platform=Evolution
# [75/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-rag__md-files?source-platform=Evolution
# [76/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-redis__queue-broker?source-platform=Evolution
# [77/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-redis__web-performance?source-platform=Evolution
# [78/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-spark__spark-delta-lake?source-platform=Evolution
# [79/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-spark__spark-iceberg?source-platform=Evolution
# [80/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-spark__spark-image-artifact-registry?source-platform=Evolution
# [81/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-spark__spark-s3?source-platform=Evolution
# [82/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-spark__spark-streaming?source-platform=Evolution
# [83/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-trino__migration-postgresql?source-platform=Evolution
# [84/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-trino__trino-iceberg?source-platform=Evolution
# [85/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-trino__trino-postgres?source-platform=Evolution
# [86/108] https://cloud.ru/docs/tutorials-evolution/list/topics/managed-trino__trino-s3?source-platform=Evolution
# [87/108] https://cloud.ru/docs/tutorials-evolution/list/topics/ml-finetuning__finetune-example?source-platform=Evolution
# [88/108] https://cloud.ru/docs/tutorials-evolution/list/topics/monitoring-and-logging__audit-logging__fluent-bit?source-platform=Evolution
# [89/108] https://cloud.ru/docs/tutorials-evolution/list/topics/monitoring-and-logging__client-log__docker-fluent-bit?source-platform=Evolution
# [90/108] https://cloud.ru/docs/tutorials-evolution/list/topics/monitoring-and-logging__client-log__fluent-bit-logaas-plugin?source-platform=Evolution
# [91/108] https://cloud.ru/docs/tutorials-evolution/list/topics/monitoring-and-logging__client-log__fluent-bit-lua-script?source-platform=Evolution
# [92/108] https://cloud.ru/docs/tutorials-evolution/list/topics/monitoring-and-logging__client-log__kubernetes?source-platform=Evolution
# [93/108] https://cloud.ru/docs/tutorials-evolution/list/topics/notebooks__comfyui-kandinsky?source-platform=Evolution
# [94/108] https://cloud.ru/docs/tutorials-evolution/list/topics/notebooks__cv-cnn?source-platform=Evolution
# [95/108] https://cloud.ru/docs/tutorials-evolution/list/topics/notebooks__cv-pretrain?source-platform=Evolution
# [96/108] https://cloud.ru/docs/tutorials-evolution/list/topics/notebooks__images-comfyui?source-platform=Evolution
# [97/108] https://cloud.ru/docs/tutorials-evolution/list/topics/notebooks__low-code-rag?source-platform=Evolution
# [98/108] https://cloud.ru/docs/tutorials-evolution/list/topics/notebooks__training-tensorboard?source-platform=Evolution
# [99/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__docker-swarm?source-platform=Evolution
# [100/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__gitverse-grafana-prometheus?source-platform=Evolution
# [101/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__kandinsky?source-platform=Evolution
# [102/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__postgresql-keycloak?source-platform=Evolution
# [103/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__postgresql-sonarqube?source-platform=Evolution
# [104/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__quantum-simulator?source-platform=Evolution
# [105/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__site-on-lemp?source-platform=Evolution
# [106/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__site-to-site-vpn?source-platform=Evolution
# [107/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__smarthome?source-platform=Evolution
# [108/108] https://cloud.ru/docs/tutorials-evolution/list/topics/vm__vm-router?source-platform=Evolution
#
# Готово! Все статьи сохранены в cloud_ru_docs.jsonl
